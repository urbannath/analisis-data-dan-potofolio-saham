# %%
# %pip install pandas_datareader yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas_datareader yfinance
# %pip install yfinance


import yfinance as yf
from pandas_datareader import data as pdr

# This is the "magic" line that fixes datareader
yf.pdr_override() 

def test_yfinance():
    # Use the fixed pdr here
    for symbol in ['AAPL', 'MSFT']:
        data = pdr.get_data_yahoo(symbol, start='2020-09-25', end='2020-10-02')
        print(data)

if __name__ == "__main__":
    test_yfinance()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 9
#       6 from pandas_datareader import data as pdr
#       8 # This is the "magic" line that fixes datareader
# ----> 9 yf.pdr_override()
#      11 def test_yfinance():
#      12     # Use the fixed pdr here
#      13     for symbol in ['AAPL', 'MSFT']:
#
# AttributeError: module 'yfinance' has no attribute 'pdr_override'

# %%
from pandas_datareader import data as pdr

def test_yfinance():
    for symbol in ['AAPL', 'MSFT', 'VFINX', 'BTC-USD']:
        print(">>", symbol, end=' ... ')
        data = pdr.get_data_yahoo(symbol, start='2020-09-25', end='2020-10-02')
        print (data)

if __name__ == "__main__":
    test_yfinance()
# Out:
# >> AAPL ...
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# Cell In[10], line 10
#       7         print (data)
#       9 if __name__ == "__main__":
# ---> 10     test_yfinance()
#
# Cell In[10], line 6, in test_yfinance()
#       4 for symbol in ['AAPL', 'MSFT', 'VFINX', 'BTC-USD']:
#       5     print(">>", symbol, end=' ... ')
# ----> 6     data = pdr.get_data_yahoo(symbol, start='2020-09-25', end='2020-10-02')
#       7     print (data)
#
# File c:\Users\debor\anaconda3\Lib\site-packages\pandas_datareader\data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File c:\Users\debor\anaconda3\Lib\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
# ...

# %%
import yfinance as yf

def test_yfinance():
    for symbol in ['AAPL', 'MSFT', 'VFINX', 'BTC-USD']:
        print(f">> Fetching {symbol}...")
        # We call yf.download directly. It returns a pandas DataFrame.
        data = yf.download(symbol, start='2020-09-25', end='2020-10-02')
        print(data)

if __name__ == "__main__":
    test_yfinance()
# Out:
# [*********************100%***********************]  1 of 1 completed
# >> Fetching AAPL...
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-09-25  108.908646  109.063845  104.437066  105.174248  149981400
# 2020-09-28  111.508163  111.857355  109.393621  111.556665  137672400
# 2020-09-29  110.664291  111.847660  110.159908  111.110486   99382200
# 2020-09-30  112.332657  113.739123  110.208419  110.373313  142675200
# 2020-10-01  113.283218  114.185294  112.352045  114.107694  116120400
# >> Fetching MSFT...
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2020-09-25  198.437912  199.602821  193.396266  194.360678  29437300
# 2020-09-28  199.984787  202.973487  198.667083  201.359780  32004900
# ...
